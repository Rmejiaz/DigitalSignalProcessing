# %% [markdown]
# # Ejemplo de filtrado de señales de EEG con diferentes tipos de filtros
#
# (Bessel, Butterworth, Chevyshev y Elíptico)
#
# ## Rafael Mejía Zuluaga
# ## rmejiaz@unal.edu.co

# %% [markdown]
# ## Descarga y acondicionamiento del dataset:

# %%
# Cargar base de datos
#id del archivo: 1sui-FJI5znNJuQOk0whM6PALI89XfKss
FILEID = "1sui-FJI5znNJuQOk0whM6PALI89XfKss"
#1sui-FJI5znNJuQOk0whM6PALI89XfKss
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id='$FILEID -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id="$FILEID -O codigos.zip && rm -rf /tmp/cookies.txt
# !unzip codigos.zip
# !dir
# !pip install mne==0.19



#importar paquetes
#importar carpeta con funciones
import sys
#agregar carpeta con funciones
sys.path.insert(1, './CodesBCIITL')
# %matplotlib inline
from MIfunctions import * #importar todas las funciones de manejo de eeg con mne

import matplotlib.pyplot as plt
import numpy as np
from mne.io import read_raw_edf
from mne.decoding import CSP
import pandas as pd
import json as  js #conda install -c jmcmurray json
import warnings


from numpy import matlib
import os
from ipywidgets import interact


from mne.datasets import eegbci
from mne.io import concatenate_raws, read_raw_edf
from mne.channels import make_standard_montage
from mne import Epochs, pick_types, events_from_annotations

#crear carpeta con resultados
from google.colab import files
import os
try:
  os.mkdir('results')
except:
  print("Carpeta results ya existe")

import shutil
from datetime import date, datetime


#cargar datos
#Descripcion base de datos
#https://drive.google.com/file/d/1354HvKfp8sMckvN2t3SR9OUo9Z0yE9Uv/view?usp=sharing

sbj = 3 #sujeto facil s03, sujeto dificil s02
name = './CodesBCIITL/data/A0' + str(sbj)
filename_train = name+'T.gdf'
Ch = np.arange(0,22)# lectura canales eeg
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
clases = [769,770] # clases izquierda y derecha -> extender a pies y lengua
vt = [-1.5,3.5] #escoger ventana de analisis : -li:lf desde el estimulo cue # probar con ventana de 1 seg
#vt = [1.5,0.5] #escoger ventana de analisis : -li:lf desde el estimulo cue # probar con ventana de 1 seg
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
i_muestras, i_clases, raw, Xraw, y, ni,m = leer_bci42a_train_full(filename_train,clases,Ch,vt)
fs = raw.info['sfreq'] #frecuencia de muestreo
print(fs)
# Out:
# --2020-11-13 16:51:32--  https://docs.google.com/uc?export=download&confirm=0ddP&id=1sui-FJI5znNJuQOk0whM6PALI89XfKss
# Resolving docs.google.com (docs.google.com)... 108.177.11.100, 108.177.11.139, 108.177.11.101, ...
# Connecting to docs.google.com (docs.google.com)|108.177.11.100|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-10-c4-docs.googleusercontent.com/docs/securesc/ma18hgj69432sgnupt63vstkt353196o/9am9sh424ftae3d41blhpgmkc41um62u/1605286275000/09173029842254050324/17825448514525246411Z/1sui-FJI5znNJuQOk0whM6PALI89XfKss?e=download [following]
# --2020-11-13 16:51:32--  https://doc-10-c4-docs.googleusercontent.com/docs/securesc/ma18hgj69432sgnupt63vstkt353196o/9am9sh424ftae3d41blhpgmkc41um62u/1605286275000/09173029842254050324/17825448514525246411Z/1sui-FJI5znNJuQOk0whM6PALI89XfKss?e=download
# Resolving doc-10-c4-docs.googleusercontent.com (doc-10-c4-docs.googleusercontent.com)... 173.194.216.132, 2607:f8b0:400c:c12::84
# Connecting to doc-10-c4-docs.googleusercontent.com (doc-10-c4-docs.googleusercontent.com)|173.194.216.132|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://docs.google.com/nonceSigner?nonce=13kpqgr5h4690&continue=https://doc-10-c4-docs.googleusercontent.com/docs/securesc/ma18hgj69432sgnupt63vstkt353196o/9am9sh424ftae3d41blhpgmkc41um62u/1605286275000/09173029842254050324/17825448514525246411Z/1sui-FJI5znNJuQOk0whM6PALI89XfKss?e%3Ddownload&hash=vkoohqin9ut4fbutslutee8aued0sm9r [following]
# --2020-11-13 16:51:32--  https://docs.google.com/nonceSigner?nonce=13kpqgr5h4690&continue=https://doc-10-c4-docs.googleusercontent.com/docs/securesc/ma18hgj69432sgnupt63vstkt353196o/9am9sh424ftae3d41blhpgmkc41um62u/1605286275000/09173029842254050324/17825448514525246411Z/1sui-FJI5znNJuQOk0whM6PALI89XfKss?e%3Ddownload&hash=vkoohqin9ut4fbutslutee8aued0sm9r
# Connecting to docs.google.com (docs.google.com)|108.177.11.100|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://doc-10-c4-docs.googleusercontent.com/docs/securesc/ma18hgj69432sgnupt63vstkt353196o/9am9sh424ftae3d41blhpgmkc41um62u/1605286275000/09173029842254050324/17825448514525246411Z/1sui-FJI5znNJuQOk0whM6PALI89XfKss?e=download&nonce=13kpqgr5h4690&user=17825448514525246411Z&hash=97jheic0lda1gqsepq4f4cap40svjkha [following]
# --2020-11-13 16:51:32--  https://doc-10-c4-docs.googleusercontent.com/docs/securesc/ma18hgj69432sgnupt63vstkt353196o/9am9sh424ftae3d41blhpgmkc41um62u/1605286275000/09173029842254050324/17825448514525246411Z/1sui-FJI5znNJuQOk0whM6PALI89XfKss?e=download&nonce=13kpqgr5h4690&user=17825448514525246411Z&hash=97jheic0lda1gqsepq4f4cap40svjkha
# Connecting to doc-10-c4-docs.googleusercontent.com (doc-10-c4-docs.googleusercontent.com)|173.194.216.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘codigos.zip’
#
# codigos.zip             [     <=>            ]  96.93M  75.2MB/s    in 1.3s
#
# 2020-11-13 16:51:34 (75.2 MB/s) - ‘codigos.zip’ saved [101634977]
#
# Archive:  codigos.zip
#    creating: CodesBCIITL/
#   inflating: CodesBCIITL/main_bci2a_pca_cka_Rel.ipynb
#   inflating: CodesBCIITL/MIfunctions.py
#   inflating: CodesBCIITL/MiniBatchCKA.py
#    creating: CodesBCIITL/data/
#   inflating: CodesBCIITL/data/A09T.gdf
#   inflating: CodesBCIITL/data/A02T.gdf
#   inflating: CodesBCIITL/data/A08T.gdf
#   inflating: CodesBCIITL/data/A03T.gdf
#    creating: CodesBCIITL/.ipynb_checkpoints/
#   inflating: CodesBCIITL/.ipynb_checkpoints/main_bci2a_pca_cka-checkpoint.ipynb
#   inflating: CodesBCIITL/.ipynb_checkpoints/main_bci2a_itlML-checkpoint.ipynb
#   inflating: CodesBCIITL/.ipynb_checkpoints/main_bci2a_pca_cka_Rel-checkpoint.ipynb
#    creating: CodesBCIITL/__pycache__/
#   inflating: CodesBCIITL/__pycache__/MIfunctions.cpython-37.pyc
#   inflating: CodesBCIITL/__pycache__/MiniBatchCKA.cpython-37.pyc
#   inflating: CodesBCIITL/__pycache__/MiniBatchMLITL.cpython-37.pyc
#    creating: CodesBCIITL/results/
#   inflating: CodesBCIITL/results/BCI2a.joblib
#   inflating: CodesBCIITL/results/BCI2aitl.joblib
#   inflating: CodesBCIITL/MiniBatchMLITL.py
#   inflating: CodesBCIITL/main_bci2a_itlML.ipynb
# CodesBCIITL  codigos.zip  sample_data
# Collecting mne==0.19
#   Downloading https://files.pythonhosted.org/packages/f5/44/b5b96426623c9dca0dfcdcfdf1f57058bb668f7c1a01bed0b0b867eb8b92/mne-0.19.0-py3-none-any.whl (6.4MB)
#      |████████████████████████████████| 6.4MB 4.3MB/s
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from mne==0.19) (1.18.5)
# Requirement already satisfied: scipy>=0.17.1 in /usr/local/lib/python3.6/dist-packages (from mne==0.19) (1.4.1)
# Installing collected packages: mne
# Successfully installed mne-0.19.0
# Extracting EDF parameters from /content/CodesBCIITL/data/A03T.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 250.0

# %% [markdown]
# ## Usamos la señal del primer canal del primer trial (del sujeto 3 de la base de datos):

# %%
trial = 0
channel = 0


plt.figure(figsize=(16,9))
plt.plot(Xraw[trial,channel])
plt.title(f"Trial {trial+1}, Channel {channel+1}",fontsize=20)
plt.grid()
plt.show()

# %% [markdown]
# ## Implementación de los filtros:

# %%
from scipy import signal

data = Xraw[trial,channel]

filters = ['Bessel', 'Butterworth', 'Chebyshev', 'Elliptic']

lowcut = 8 
highcut = 12
order = 5
nyq = 0.5 * fs
low = lowcut / nyq
high = highcut / nyq


for filter in filters:

  plt.figure(figsize=(16,5))


  if (filter == "Bessel"):
    plt.suptitle(f"{filter} Filter",fontsize=20,y=1.1)
    b, a = signal.bessel(order,[low, high], btype='band')
  elif (filter == "Butterworth"):
    plt.suptitle(f"{filter} Filter",fontsize=20,y=1.1)
    b, a = signal.butter(order,[low, high], btype='band')
  elif (filter == "Chebyshev"):
    plt.suptitle(f"{filter} Filter",fontsize=20,y=1.1)
    b, a = signal.cheby1(order,2,[low, high], btype='band', )
  elif (filter == "Elliptic"):
    plt.suptitle(f"{filter} Filter",fontsize=20,y=1.1)
    b, a = signal.ellip(order,1,40,[low, high], btype='band', )


  w, h = signal.freqz(b,a,fs=fs)

  plt.subplot(121)
  plt.plot(w, 20 * np.log10(abs(h)))
  
  plt.semilogx(w, 20 * np.log10(abs(h)))
  plt.xlabel('Frequency [Hz]')
  plt.ylabel('Amplitude response [dB]')
  plt.grid()
  plt.title("Filter Spectrum")

  plt.subplot(122)
  
  plt.plot(signal.filtfilt(b,a,data))
  plt.grid()
  plt.xlabel("Samples [k]")
  plt.title("Filtered Signal")
  
  plt.tight_layout()
  plt.show()
